# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvagyam/Business-Analyst-Assignment/blob/main/AssignmentBA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_excel('/content/Assignment - 1.xlsx',sheet_name = 'Ecomm')
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# 1              Mobile                  3        Single                7
# 2              Mobile                  3        Single                6
# 3  Laptop & Accessory                  5        Single                8
# 4              Mobile                  5        Single                3
#
#    Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0         1                         11.0         1.0         1.0
# 1         1                         15.0         0.0         1.0
# 2         1                         14.0         0.0         1.0
# 3         0                         23.0         0.0         1.0
# 4         0                         11.0         1.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0          159.93
# 1                0.0          120.90
# 2                3.0          120.28
# 3                3.0          134.07
# 4                3.0          129.60

# %%
df.shape
# Out:
# (5630, 20)

# %%
df.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                 float64
# dtype: object

# %% [markdown]
# #1. Data Cleaning

# %%
#making changes in dataset to reduce redundancy of values
df['PreferredLoginDevice'].replace({'Phone':'Mobile Phone'},inplace=True)
df['PreferredPaymentMode'].replace({'Cash on Delivery':'COD', 'CC':'Credit Card'},inplace=True)
df['PreferedOrderCat'].replace({'Mobile':'Mobile Phone'},inplace=True)
for column in df:
  print(f'{column} : {df[column].unique()}')
# Out:
# CustomerID : [50001 50002 50003 ... 55628 55629 55630]
# Churn : [1 0]
# Tenure : [ 4. nan  0. 13. 11.  9. 19. 20. 14.  8. 18.  5.  2. 30.  1. 23.  3. 29.
#   6. 26. 28.  7. 24. 25. 10. 15. 22. 27. 16. 12. 21. 17. 50. 60. 31. 51.
#  61.]
# PreferredLoginDevice : ['Mobile Phone' 'Computer']
# CityTier : [3 1 2]
# WarehouseToHome : [  6.   8.  30.  15.  12.  22.  11.   9.  31.  18.  13.  20.  29.  28.
#   26.  14.  nan  10.  27.  17.  23.  33.  19.  35.  24.  16.  25.  32.
#   34.   5.  21. 126.   7.  36. 127.]
# PreferredPaymentMode : ['Debit Card' 'UPI' 'Credit Card' 'COD' 'E wallet']
# Gender : ['Female' 'Male']
# HourSpendOnApp : [ 3.  2. nan  1.  0.  4.  5.]
# NumberOfDeviceRegistered : [3 4 5 2 1 6]
# PreferedOrderCat : ['Laptop & Accessory' 'Mobile Phone' 'Others' 'Fashion' 'Grocery']
# SatisfactionScore : [2 3 5 4 1]
# MaritalStatus : ['Single' 'Divorced' 'Married']
# NumberOfAddress : [ 9  7  6  8  3  2  4 10  1  5 19 21 11 20 22]
# Complain : [1 0]
# OrderAmountHikeFromlastYear : [11. 15. 14. 23. 22. 16. 12. nan 13. 17. 18. 24. 19. 20. 21. 25. 26.]
# CouponUsed : [ 1.  0.  4.  2.  9.  6. 11. nan  7. 12. 10.  5.  3. 13. 15.  8. 14. 16.]
# OrderCount : [ 1.  6.  2. 15.  4.  7.  3.  9. nan 11.  5. 12. 10.  8. 13. 14. 16.]
# DaySinceLastOrder : [ 5.  0.  3.  7.  2.  1.  8.  6.  4. 15.  9. 11. 10. nan 13. 12. 17. 16.
#  14. 30. 46. 18. 31.]
# CashbackAmount : [159.93 120.9  120.28 ... 173.77 287.91 173.78]

# %%
#dropping the null values from the dataset
df.dropna(how = 'any',axis=0,inplace=True)

# %%
df.Churn.value_counts()
# Out:
# 0    3143
# 1     631
# Name: Churn, dtype: int64

# %%
#correcting the datatype of the columns
column_to_int = ['CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'OrderAmountHikeFromlastYear', 'Tenure', 'WarehouseToHome', 'HourSpendOnApp']
for col in column_to_int:
  df[col] = df[col].astype(int)

# %%
df.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                           int64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                  int64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                   int64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear      int64
# CouponUsed                       int64
# OrderCount                       int64
# DaySinceLastOrder                int64
# CashbackAmount                 float64
# dtype: object

# %%
#converting the data values to numerical values for better computation for the algorithm
df['Gender'].replace({'Female':1, 'Male': 0},inplace = True)
df.Gender.unique()
# Out:
# array([1, 0])

# %%
#applying one hot encoding to categorized data
df_clean =pd.get_dummies(data = df, columns=['PreferredLoginDevice','PreferredPaymentMode','PreferedOrderCat', 'MaritalStatus','CityTier'])
df_clean.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'WarehouseToHome', 'Gender',
#        'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore',
#        'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear',
#        'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount',
#        'PreferredLoginDevice_Computer', 'PreferredLoginDevice_Mobile Phone',
#        'PreferredPaymentMode_COD', 'PreferredPaymentMode_Credit Card',
#        'PreferredPaymentMode_Debit Card', 'PreferredPaymentMode_E wallet',
#        'PreferredPaymentMode_UPI', 'PreferedOrderCat_Fashion',
#        'PreferedOrderCat_Grocery', 'PreferedOrderCat_Laptop & Accessory',
#        'PreferedOrderCat_Mobile Phone', 'PreferedOrderCat_Others',
#        'MaritalStatus_Divorced', 'MaritalStatus_Married',
#        'MaritalStatus_Single', 'CityTier_1', 'CityTier_2', 'CityTier_3'],
#       dtype='object')

# %%
df_clean.shape
# Out:
# (3774, 33)

# %%
#making data scale to 0 to 1 for better and faster computation
col_to_scale = ['Tenure','WarehouseToHome','HourSpendOnApp','NumberOfDeviceRegistered','SatisfactionScore','NumberOfAddress','OrderAmountHikeFromlastYear','CouponUsed','OrderCount','DaySinceLastOrder','CashbackAmount']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_clean[col_to_scale] = scaler.fit_transform(df_clean[col_to_scale])

# %%
df_clean.drop('CustomerID',axis='columns',inplace=True)

# %%
for column in df_clean:
  print(f'{column} : {df_clean[column].unique()}')

# data has been scaled
# Out:
# Churn : [1 0]
# Tenure : [0.07843137 0.         0.21568627 0.17647059 0.37254902 0.39215686
#  0.2745098  0.15686275 0.09803922 0.03921569 0.58823529 0.25490196
#  0.05882353 0.35294118 0.56862745 0.45098039 0.50980392 0.1372549
#  0.19607843 0.29411765 0.43137255 0.01960784 0.52941176 0.49019608
#  0.54901961 0.47058824 0.23529412 0.11764706 0.31372549 0.41176471
#  0.33333333 0.98039216 0.60784314 1.        ]
# WarehouseToHome : [0.00819672 0.08196721 0.13934426 0.04918033 0.06557377 0.12295082
#  0.05737705 0.19672131 0.17213115 0.07377049 0.04098361 0.20491803
#  0.02459016 0.10655738 0.1147541  0.18032787 0.24590164 0.1557377
#  0.09016393 0.2295082  0.22131148 0.03278689 0.14754098 0.09836066
#  0.23770492 0.21311475 0.18852459 0.16393443 0.13114754 0.
#  0.99180328 0.01639344 0.25409836 1.        ]
# Gender : [1 0]
# HourSpendOnApp : [0.6 0.4 0.2 0.8 0.  1. ]
# NumberOfDeviceRegistered : [0.4 0.6 0.8 0.2 0.  1. ]
# SatisfactionScore : [0.25 1.   0.5  0.75 0.  ]
# NumberOfAddress : [0.38095238 0.33333333 0.04761905 0.42857143 0.         0.19047619
#  0.14285714 0.0952381  0.23809524 0.28571429 0.95238095 0.47619048
#  0.9047619  1.        ]
# Complain : [1 0]
# OrderAmountHikeFromlastYear : [0.         0.8        0.73333333 0.13333333 0.4        0.33333333
#  0.86666667 0.46666667 0.06666667 0.26666667 0.2        0.6
#  0.93333333 0.53333333 0.66666667 1.        ]
# CouponUsed : [0.0625 0.     0.25   0.125  0.375  0.6875 0.4375 0.75   0.1875 0.3125
#  0.5625 0.8125 0.5    0.625  1.    ]
# OrderCount : [0.         0.33333333 0.06666667 0.2        0.4        0.93333333
#  0.13333333 0.53333333 0.26666667 0.73333333 0.6        0.66666667
#  0.46666667 0.8        0.86666667 1.        ]
# DaySinceLastOrder : [0.10869565 0.06521739 0.15217391 0.         0.04347826 0.13043478
#  0.08695652 0.19565217 0.23913043 0.02173913 0.17391304 0.2826087
#  0.2173913  0.26086957 0.32608696 0.36956522 0.30434783 0.65217391
#  1.         0.34782609 0.39130435 0.67391304]
# CashbackAmount : [0.49210745 0.41253577 0.4282901  ... 0.99489215 0.53472415 0.80217853]
# PreferredLoginDevice_Computer : [0 1]
# PreferredLoginDevice_Mobile Phone : [1 0]
# PreferredPaymentMode_COD : [0 1]
# PreferredPaymentMode_Credit Card : [0 1]
# PreferredPaymentMode_Debit Card : [1 0]
# PreferredPaymentMode_E wallet : [0 1]
# PreferredPaymentMode_UPI : [0 1]
# PreferedOrderCat_Fashion : [0 1]
# PreferedOrderCat_Grocery : [0 1]
# PreferedOrderCat_Laptop & Accessory : [1 0]
# PreferedOrderCat_Mobile Phone : [0 1]
# PreferedOrderCat_Others : [0 1]
# MaritalStatus_Divorced : [0 1]
# MaritalStatus_Married : [0 1]
# MaritalStatus_Single : [1 0]
# CityTier_1 : [0 1]
# CityTier_2 : [0 1]
# CityTier_3 : [1 0]

# %%
#checking correlation between the columns
df_clean.corr()
# Out:
#                                         Churn    Tenure  WarehouseToHome  \
# Churn                                1.000000 -0.340013         0.087318
# Tenure                              -0.340013  1.000000        -0.016353
# WarehouseToHome                      0.087318 -0.016353         1.000000
# Gender                              -0.033792  0.052123        -0.035581
# HourSpendOnApp                       0.060845 -0.029818         0.052731
# NumberOfDeviceRegistered             0.149041 -0.058752         0.024582
# SatisfactionScore                    0.095759 -0.009972         0.000434
# NumberOfAddress                      0.076336  0.196547         0.003422
# Complain                             0.238137 -0.035228         0.003829
# OrderAmountHikeFromlastYear          0.017193  0.012197         0.031975
# CouponUsed                           0.010982  0.075959        -0.014311
# OrderCount                          -0.001962  0.112339         0.008800
# DaySinceLastOrder                   -0.139254  0.118932         0.010646
# CashbackAmount                      -0.058756  0.213852        -0.012433
# PreferredLoginDevice_Computer        0.040890 -0.010308         0.022101
# PreferredLoginDevice_Mobile Phone   -0.040890  0.010308        -0.022101
# PreferredPaymentMode_COD             0.053064  0.001056        -0.006874
# PreferredPaymentMode_Credit Card    -0.022753 -0.030781         0.037364
# PreferredPaymentMode_Debit Card     -0.039232  0.040958        -0.041475
# PreferredPaymentMode_E wallet        0.043972  0.016709         0.033578
# PreferredPaymentMode_UPI             0.000938 -0.043942        -0.021470
# PreferedOrderCat_Fashion             0.013086  0.130259        -0.009435
# PreferedOrderCat_Grocery            -0.017880  0.091251         0.003512
# PreferedOrderCat_Laptop & Accessory -0.184584  0.104482         0.043231
# PreferedOrderCat_Mobile Phone        0.183750 -0.219010        -0.033932
# PreferedOrderCat_Others              0.010208  0.103702        -0.035530
# MaritalStatus_Divorced              -0.013023  0.015788        -0.013650
# MaritalStatus_Married               -0.159808  0.085990         0.038336
# MaritalStatus_Single                 0.179481 -0.103150        -0.030496
# CityTier_1                          -0.071851  0.052275         0.005213
# CityTier_2                           0.001592  0.017008        -0.048595
# CityTier_3                           0.072950 -0.060373         0.014183
#
#                                        Gender  HourSpendOnApp  \
# Churn                               -0.033792        0.060845
# Tenure                               0.052123       -0.029818
# WarehouseToHome                     -0.035581        0.052731
# Gender                               1.000000        0.009952
# HourSpendOnApp                       0.009952        1.000000
# NumberOfDeviceRegistered             0.026706        0.293021
# SatisfactionScore                    0.032398        0.039879
# NumberOfAddress                      0.030980        0.124962
# Complain                             0.039522        0.020413
# OrderAmountHikeFromlastYear         -0.010081        0.096827
# CouponUsed                           0.041493        0.160239
# OrderCount                           0.035418        0.092601
# DaySinceLastOrder                    0.018478        0.019526
# CashbackAmount                       0.020263        0.131281
# PreferredLoginDevice_Computer       -0.025482       -0.004911
# PreferredLoginDevice_Mobile Phone    0.025482        0.004911
# PreferredPaymentMode_COD            -0.022402        0.001983
# PreferredPaymentMode_Credit Card     0.026315        0.022119
# PreferredPaymentMode_Debit Card     -0.004968        0.020115
# PreferredPaymentMode_E wallet        0.022827       -0.039522
# PreferredPaymentMode_UPI            -0.039949       -0.030052
# PreferedOrderCat_Fashion             0.009374       -0.147830
# PreferedOrderCat_Grocery            -0.005292       -0.017382
# PreferedOrderCat_Laptop & Accessory  0.043367       -0.130819
# PreferedOrderCat_Mobile Phone       -0.052031        0.233904
# PreferedOrderCat_Others              0.006532        0.023109
# MaritalStatus_Divorced               0.012541        0.018024
# MaritalStatus_Married               -0.035047        0.022257
# MaritalStatus_Single                 0.027833       -0.037134
# CityTier_1                          -0.009022        0.067968
# CityTier_2                          -0.043250       -0.000672
# CityTier_3                           0.026616       -0.069343
#
#                                      NumberOfDeviceRegistered  \
# Churn                                                0.149041
# Tenure                                              -0.058752
# WarehouseToHome                                      0.024582
# Gender                                               0.026706
# HourSpendOnApp                                       0.293021
# NumberOfDeviceRegistered                             1.000000
# SatisfactionScore                                   -0.017788
# NumberOfAddress                                      0.066684
# Complain                                             0.018881
# OrderAmountHikeFromlastYear                          0.083342
# CouponUsed                                           0.114066
# OrderCount                                           0.069559
# DaySinceLastOrder                                   -0.049817
# CashbackAmount                                       0.113504
# PreferredLoginDevice_Computer                        0.025628
# PreferredLoginDevice_Mobile Phone                   -0.025628
# PreferredPaymentMode_COD                            -0.001948
# PreferredPaymentMode_Credit Card                    -0.006730
# PreferredPaymentMode_Debit Card                      0.007461
# PreferredPaymentMode_E wallet                       -0.008889
# PreferredPaymentMode_UPI                             0.010839
# PreferedOrderCat_Fashion                            -0.091604
# PreferedOrderCat_Grocery                             0.022548
# PreferedOrderCat_Laptop & Accessory                 -0.080608
# PreferedOrderCat_Mobile Phone                        0.138667
# PreferedOrderCat_Others                              0.035364
# MaritalStatus_Divorced                              -0.001099
# MaritalStatus_Married                               -0.064517
# MaritalStatus_Single                                 0.069345
# CityTier_1                                           0.003889
# CityTier_2                                           0.022722
# CityTier_3                                          -0.013112
#
#                                      SatisfactionScore  NumberOfAddress  \
# Churn                                         0.095759         0.076336
# Tenure                                       -0.009972         0.196547
# WarehouseToHome                               0.000434         0.003422
# Gender                                        0.032398         0.030980
# HourSpendOnApp                                0.039879         0.124962
# NumberOfDeviceRegistered                     -0.017788         0.066684
# SatisfactionScore                             1.000000         0.054627
# NumberOfAddress                               0.054627         1.000000
# Complain                                     -0.044533        -0.017363
# OrderAmountHikeFromlastYear                  -0.008143         0.010275
# CouponUsed                                    0.006687        -0.017851
# OrderCount                                   -0.004622        -0.079413
# DaySinceLastOrder                             0.012950        -0.148784
# CashbackAmount                                0.012061         0.096752
# PreferredLoginDevice_Computer                -0.035021        -0.024398
# PreferredLoginDevice_Mobile Phone             0.035021         0.024398
# PreferredPaymentMode_COD                      0.013364        -0.010908
# PreferredPaymentMode_Credit Card              0.045715         0.007870
# PreferredPaymentMode_Debit Card              -0.073269         0.013272
# PreferredPaymentMode_E wallet                 0.026658        -0.027925
# PreferredPaymentMode_UPI                      0.009321         0.007556
# PreferedOrderCat_Fashion                      0.016587        -0.040136
# PreferedOrderCat_Grocery                      0.027097        -0.005968
# PreferedOrderCat_Laptop & Accessory          -0.025448         0.059515
# PreferedOrderCat_Mobile Phone                 0.008771        -0.033983
# PreferedOrderCat_Others                       0.030401        -0.004349
# MaritalStatus_Divorced                        0.051528        -0.024802
# MaritalStatus_Married                        -0.012167        -0.001463
# MaritalStatus_Single                         -0.025659         0.020125
# CityTier_1                                    0.015915         0.038587
# CityTier_2                                    0.015125         0.032438
# CityTier_3                                   -0.022377        -0.052553
#
#                                      Complain  OrderAmountHikeFromlastYear  \
# Churn                                0.238137                     0.017193
# Tenure                              -0.035228                     0.012197
# WarehouseToHome                      0.003829                     0.031975
# Gender                               0.039522                    -0.010081
# HourSpendOnApp                       0.020413                     0.096827
# NumberOfDeviceRegistered             0.018881                     0.083342
# SatisfactionScore                   -0.044533                    -0.008143
# NumberOfAddress                     -0.017363                     0.010275
# Complain                             1.000000                     0.003260
# OrderAmountHikeFromlastYear          0.003260                     1.000000
# CouponUsed                           0.005472                     0.048959
# OrderCount                          -0.001917                     0.042950
# DaySinceLastOrder                   -0.056315                     0.017716
# CashbackAmount                       0.010389                     0.014215
# PreferredLoginDevice_Computer       -0.014878                    -0.000220
# PreferredLoginDevice_Mobile Phone    0.014878                     0.000220
# PreferredPaymentMode_COD            -0.021310                    -0.055174
# PreferredPaymentMode_Credit Card     0.007578                     0.029865
# PreferredPaymentMode_Debit Card     -0.002413                     0.010242
# PreferredPaymentMode_E wallet        0.001807                    -0.036139
# PreferredPaymentMode_UPI             0.012421                     0.033331
# PreferedOrderCat_Fashion            -0.000022                    -0.051335
# PreferedOrderCat_Grocery             0.004534                     0.041476
# PreferedOrderCat_Laptop & Accessory -0.018126                    -0.024964
# PreferedOrderCat_Mobile Phone        0.017412                     0.054050
# PreferedOrderCat_Others              0.007866                     0.021090
# MaritalStatus_Divorced               0.012777                    -0.014517
# MaritalStatus_Married               -0.000364                     0.014894
# MaritalStatus_Single                -0.009180                    -0.004949
# CityTier_1                           0.011890                     0.032166
# CityTier_2                          -0.030390                    -0.027561
# CityTier_3                           0.000031                    -0.021872
#
#                                      ...  PreferedOrderCat_Grocery  \
# Churn                                ...                 -0.017880
# Tenure                               ...                  0.091251
# WarehouseToHome                      ...                  0.003512
# Gender                               ...                 -0.005292
# HourSpendOnApp                       ...                 -0.017382
# NumberOfDeviceRegistered             ...                  0.022548
# SatisfactionScore                    ...                  0.027097
# NumberOfAddress                      ...                 -0.005968
# Complain                             ...                  0.004534
# OrderAmountHikeFromlastYear          ...                  0.041476
# CouponUsed                           ...                  0.078182
# OrderCount                           ...                  0.126821
# DaySinceLastOrder                    ...                  0.035204
# CashbackAmount                       ...                  0.014736
# PreferredLoginDevice_Computer        ...                  0.032595
# PreferredLoginDevice_Mobile Phone    ...                 -0.032595
# PreferredPaymentMode_COD             ...                  0.010220
# PreferredPaymentMode_Credit Card     ...                  0.031104
# PreferredPaymentMode_Debit Card      ...                 -0.019560
# PreferredPaymentMode_E wallet        ...                 -0.014552
# PreferredPaymentMode_UPI             ...                 -0.011405
# PreferedOrderCat_Fashion             ...                 -0.014552
# PreferedOrderCat_Grocery             ...                  1.000000
# PreferedOrderCat_Laptop & Accessory  ...                 -0.041501
# PreferedOrderCat_Mobile Phone        ...                 -0.029711
# PreferedOrderCat_Others              ...                 -0.002762
# MaritalStatus_Divorced               ...                 -0.016429
# MaritalStatus_Married                ...                  0.024625
# MaritalStatus_Single                 ...                 -0.013853
# CityTier_1                           ...                  0.003237
# CityTier_2                           ...                 -0.007861
# CityTier_3                           ...                 -0.000157
#
#                                      PreferedOrderCat_Laptop & Accessory  \
# Churn                                                          -0.184584
# Tenure                                                          0.104482
# WarehouseToHome                                                 0.043231
# Gender                                                          0.043367
# HourSpendOnApp                                                 -0.130819
# NumberOfDeviceRegistered                                       -0.080608
# SatisfactionScore                                              -0.025448
# NumberOfAddress                                                 0.059515
# Complain                                                       -0.018126
# OrderAmountHikeFromlastYear                                    -0.024964
# CouponUsed                                                     -0.038409
# OrderCount                                                     -0.018610
# DaySinceLastOrder                                               0.122257
# CashbackAmount                                                  0.101787
# PreferredLoginDevice_Computer                                   0.056688
# PreferredLoginDevice_Mobile Phone                              -0.056688
# PreferredPaymentMode_COD                                       -0.075688
# PreferredPaymentMode_Credit Card                               -0.051996
# PreferredPaymentMode_Debit Card                                -0.001249
# PreferredPaymentMode_E wallet                                   0.141394
# PreferredPaymentMode_UPI                                        0.003837
# PreferedOrderCat_Fashion                                       -0.379275
# PreferedOrderCat_Grocery                                       -0.041501
# PreferedOrderCat_Laptop & Accessory                             1.000000
# PreferedOrderCat_Mobile Phone                                  -0.774351
# PreferedOrderCat_Others                                        -0.071997
# MaritalStatus_Divorced                                         -0.000340
# MaritalStatus_Married                                           0.057496
# MaritalStatus_Single                                           -0.060812
# CityTier_1                                                     -0.224248
# CityTier_2                                                     -0.070654
# CityTier_3                                                      0.258061
#
#                                      PreferedOrderCat_Mobile Phone  \
# Churn                                                     0.183750
# Tenure                                                   -0.219010
# WarehouseToHome                                          -0.033932
# Gender                                                   -0.052031
# HourSpendOnApp                                            0.233904
# NumberOfDeviceRegistered                                  0.138667
# SatisfactionScore                                         0.008771
# NumberOfAddress                                          -0.033983
# Complain                                                  0.017412
# OrderAmountHikeFromlastYear                               0.054050
# CouponUsed                                               -0.031276
# OrderCount                                               -0.112093
# DaySinceLastOrder                                        -0.246859
# CashbackAmount                                           -0.477305
# PreferredLoginDevice_Computer                            -0.025778
# PreferredLoginDevice_Mobile Phone                         0.025778
# PreferredPaymentMode_COD                                  0.067841
# PreferredPaymentMode_Credit Card                          0.085910
# PreferredPaymentMode_Debit Card                           0.001656
# PreferredPaymentMode_E wallet                            -0.195910
# PreferredPaymentMode_UPI                                  0.011210
# PreferedOrderCat_Fashion                                 -0.271527
# PreferedOrderCat_Grocery                                 -0.029711
# PreferedOrderCat_Laptop & Accessory                      -0.774351
# PreferedOrderCat_Mobile Phone                             1.000000
# PreferedOrderCat_Others                                  -0.051543
# MaritalStatus_Divorced                                   -0.001710
# MaritalStatus_Married                                    -0.071872
# MaritalStatus_Single                                      0.077614
# CityTier_1                                                0.284258
# CityTier_2                                                0.083749
# CityTier_3                                               -0.324784
#
#                                      PreferedOrderCat_Others  \
# Churn                                               0.010208
# Tenure                                              0.103702
# WarehouseToHome                                    -0.035530
# Gender                                              0.006532
# HourSpendOnApp                                      0.023109
# NumberOfDeviceRegistered                            0.035364
# SatisfactionScore                                   0.030401
# NumberOfAddress                                    -0.004349
# Complain                                            0.007866
# OrderAmountHikeFromlastYear                         0.021090
# CouponUsed                                          0.082800
# OrderCount                                          0.118690
# DaySinceLastOrder                                   0.071340
# CashbackAmount                                      0.443994
# PreferredLoginDevice_Computer                       0.005916
# PreferredLoginDevice_Mobile Phone                  -0.005916
# PreferredPaymentMode_COD                            0.004453
# PreferredPaymentMode_Credit Card                   -0.021075
# PreferredPaymentMode_Debit Card                     0.028682
# PreferredPaymentMode_E wallet                      -0.001349
# PreferredPaymentMode_UPI                           -0.019785
# PreferedOrderCat_Fashion                           -0.025246
# PreferedOrderCat_Grocery                           -0.002762
# PreferedOrderCat_Laptop & Accessory                -0.071997
# PreferedOrderCat_Mobile Phone                      -0.051543
# PreferedOrderCat_Others                             1.000000
# MaritalStatus_Divorced                              0.004273
# MaritalStatus_Married                               0.019615
# MaritalStatus_Single                               -0.024032
# CityTier_1                                          0.013570
# CityTier_2                                         -0.013638
# CityTier_3                                         -0.008419
#
#                                      MaritalStatus_Divorced  \
# Churn                                             -0.013023
# Tenure                                             0.015788
# WarehouseToHome                                   -0.013650
# Gender                                             0.012541
# HourSpendOnApp                                     0.018024
# NumberOfDeviceRegistered                          -0.001099
# SatisfactionScore                                  0.051528
# NumberOfAddress                                   -0.024802
# Complain                                           0.012777
# OrderAmountHikeFromlastYear                       -0.014517
# CouponUsed                                         0.043312
# OrderCount                                         0.022122
# DaySinceLastOrder                                 -0.007111
# CashbackAmount                                     0.013801
# PreferredLoginDevice_Computer                     -0.016560
# PreferredLoginDevice_Mobile Phone                  0.016560
# PreferredPaymentMode_COD                           0.008876
# PreferredPaymentMode_Credit Card                   0.001657
# PreferredPaymentMode_Debit Card                   -0.010594
# PreferredPaymentMode_E wallet                      0.020559
# PreferredPaymentMode_UPI                          -0.017968
# PreferedOrderCat_Fashion                           0.004190
# PreferedOrderCat_Grocery                          -0.016429
# PreferedOrderCat_Laptop & Accessory               -0.000340
# PreferedOrderCat_Mobile Phone                     -0.001710
# PreferedOrderCat_Others                            0.004273
# MaritalStatus_Divorced                             1.000000
# MaritalStatus_Married                             -0.432989
# MaritalStatus_Single                              -0.288871
# CityTier_1                                        -0.019017
# CityTier_2                                         0.002237
# CityTier_3                                         0.018579
#
#                                      MaritalStatus_Married  \
# Churn                                            -0.159808
# Tenure                                            0.085990
# WarehouseToHome                                   0.038336
# Gender                                           -0.035047
# HourSpendOnApp                                    0.022257
# NumberOfDeviceRegistered                         -0.064517
# SatisfactionScore                                -0.012167
# NumberOfAddress                                  -0.001463
# Complain                                         -0.000364
# OrderAmountHikeFromlastYear                       0.014894
# CouponUsed                                        0.010976
# OrderCount                                        0.043676
# DaySinceLastOrder                                 0.034002
# CashbackAmount                                    0.034234
# PreferredLoginDevice_Computer                    -0.006364
# PreferredLoginDevice_Mobile Phone                 0.006364
# PreferredPaymentMode_COD                         -0.020670
# PreferredPaymentMode_Credit Card                 -0.000776
# PreferredPaymentMode_Debit Card                  -0.011571
# PreferredPaymentMode_E wallet                     0.017060
# PreferredPaymentMode_UPI                          0.024753
# PreferedOrderCat_Fashion                          0.010466
# PreferedOrderCat_Grocery                          0.024625
# PreferedOrderCat_Laptop & Accessory               0.057496
# PreferedOrderCat_Mobile Phone                    -0.071872
# PreferedOrderCat_Others                           0.019615
# MaritalStatus_Divorced                           -0.432989
# MaritalStatus_Married                             1.000000
# MaritalStatus_Single                             -0.737892
# CityTier_1                                        0.021283
# CityTier_2                                        0.039033
# CityTier_3                                       -0.037479
#
#                                      MaritalStatus_Single  CityTier_1  \
# Churn                                            0.179481   -0.071851
# Tenure                                          -0.103150    0.052275
# WarehouseToHome                                 -0.030496    0.005213
# Gender                                           0.027833   -0.009022
# HourSpendOnApp                                  -0.037134    0.067968
# NumberOfDeviceRegistered                         0.069345    0.003889
# SatisfactionScore                               -0.025659    0.015915
# NumberOfAddress                                  0.020125    0.038587
# Complain                                        -0.009180    0.011890
# OrderAmountHikeFromlastYear                     -0.004949    0.032166
# CouponUsed                                      -0.044087   -0.008889
# OrderCount                                      -0.062952   -0.025214
# DaySinceLastOrder                               -0.030789   -0.009286
# CashbackAmount                                  -0.046693   -0.136400
# PreferredLoginDevice_Computer                    0.019158    0.001085
# PreferredLoginDevice_Mobile Phone               -0.019158   -0.001085
# PreferredPaymentMode_COD                         0.015308    0.049224
# PreferredPaymentMode_Credit Card                -0.000417    0.169637
# PreferredPaymentMode_Debit Card                  0.020221    0.134933
# PreferredPaymentMode_E wallet                   -0.033513   -0.473274
# PreferredPaymentMode_UPI                        -0.012836   -0.024524
# PreferedOrderCat_Fashion                        -0.014253   -0.078256
# PreferedOrderCat_Grocery                        -0.013853    0.003237
# PreferedOrderCat_Laptop & Accessory             -0.060812   -0.224248
# PreferedOrderCat_Mobile Phone                    0.077614    0.284258
# PreferedOrderCat_Others                         -0.024032    0.013570
# MaritalStatus_Divorced                          -0.288871   -0.019017
# MaritalStatus_Married                           -0.737892    0.021283
# MaritalStatus_Single                             1.000000   -0.008365
# CityTier_1                                      -0.008365    1.000000
# CityTier_2                                      -0.043132   -0.255667
# CityTier_3                                       0.025895   -0.921495
#
#                                      CityTier_2  CityTier_3
# Churn                                  0.001592    0.072950
# Tenure                                 0.017008   -0.060373
# WarehouseToHome                       -0.048595    0.014183
# Gender                                -0.043250    0.026616
# HourSpendOnApp                        -0.000672   -0.069343
# NumberOfDeviceRegistered               0.022722   -0.013112
# SatisfactionScore                      0.015125   -0.022377
# NumberOfAddress                        0.032438   -0.052553
# Complain                              -0.030390    0.000031
# OrderAmountHikeFromlastYear           -0.027561   -0.021872
# CouponUsed                            -0.020422    0.017309
# OrderCount                            -0.044386    0.043655
# DaySinceLastOrder                     -0.023294    0.018869
# CashbackAmount                        -0.028384    0.151105
# PreferredLoginDevice_Computer         -0.004623    0.000746
# PreferredLoginDevice_Mobile Phone      0.004623   -0.000746
# PreferredPaymentMode_COD              -0.014657   -0.044527
# PreferredPaymentMode_Credit Card      -0.052403   -0.152691
# PreferredPaymentMode_Debit Card       -0.058180   -0.114826
# PreferredPaymentMode_E wallet         -0.071844    0.513594
# PreferredPaymentMode_UPI               0.303275   -0.096720
# PreferedOrderCat_Fashion              -0.011073    0.084599
# PreferedOrderCat_Grocery              -0.007861   -0.000157
# PreferedOrderCat_Laptop & Accessory   -0.070654    0.258061
# PreferedOrderCat_Mobile Phone          0.083749   -0.324784
# PreferedOrderCat_Others               -0.013638   -0.008419
# MaritalStatus_Divorced                 0.002237    0.018579
# MaritalStatus_Married                  0.039033   -0.037479
# MaritalStatus_Single                  -0.043132    0.025895
# CityTier_1                            -0.255667   -0.921495
# CityTier_2                             1.000000   -0.139885
# CityTier_3                            -0.139885    1.000000
#
# [32 rows x 32 columns]

# %% [markdown]
# #2. Creating Models for Prediction

# %%
x = df_clean.drop('Churn',axis='columns')
y = df_clean['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 5)

# %%
x_train.shape
# Out:
# (3019, 31)

# %%
x_test.shape
# Out:
# (755, 31)

# %% [markdown]
# ##a. ANN Prediction

# %%
#checking the prediction with ANN
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(21,input_shape=(31,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')

])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(x_train,y_train,epochs = 70)
# Out:
# Epoch 1/70
# 95/95 [==============================] - 1s 2ms/step - loss: 0.5244 - accuracy: 0.7721
# Epoch 2/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8344
# Epoch 3/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8377
# Epoch 4/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8493
# Epoch 5/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3524 - accuracy: 0.8549
# Epoch 6/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8592
# Epoch 7/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8615
# Epoch 8/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3220 - accuracy: 0.8688
# Epoch 9/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3150 - accuracy: 0.8702
# Epoch 10/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3075 - accuracy: 0.8774
# Epoch 11/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.3007 - accuracy: 0.8778
# Epoch 12/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.8827
# Epoch 13/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8827
# Epoch 14/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2853 - accuracy: 0.8877
# Epoch 15/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.8887
# Epoch 16/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8923
# Epoch 17/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.8963
# Epoch 18/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8963
# Epoch 19/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.9020
# Epoch 20/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2643 - accuracy: 0.9016
# Epoch 21/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.8996
# Epoch 22/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9049
# Epoch 23/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2585 - accuracy: 0.9016
# Epoch 24/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.9023
# Epoch 25/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.9033
# Epoch 26/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.9016
# Epoch 27/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.9056
# Epoch 28/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2515 - accuracy: 0.9043
# Epoch 29/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2503 - accuracy: 0.9063
# Epoch 30/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2496 - accuracy: 0.9059
# Epoch 31/70
# 95/95 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9046
# Epoch 32/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.9073
# Epoch 33/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9063
# Epoch 34/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.9076
# Epoch 35/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2441 - accuracy: 0.9082
# Epoch 36/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.9109
# Epoch 37/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9089
# Epoch 38/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9079
# Epoch 39/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9102
# Epoch 40/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9112
# Epoch 41/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9112
# Epoch 42/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9129
# Epoch 43/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9086
# Epoch 44/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9069
# Epoch 45/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2375 - accuracy: 0.9119
# Epoch 46/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9142
# Epoch 47/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 0.9172
# Epoch 48/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9122
# Epoch 49/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9149
# Epoch 50/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.9149
# Epoch 51/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9135
# Epoch 52/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.9145
# Epoch 53/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9149
# Epoch 54/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2307 - accuracy: 0.9179
# Epoch 55/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9182
# Epoch 56/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9179
# Epoch 57/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9159
# Epoch 58/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2268 - accuracy: 0.9208
# Epoch 59/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9172
# Epoch 60/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9165
# Epoch 61/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9208
# Epoch 62/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9198
# Epoch 63/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.9215
# Epoch 64/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9198
# Epoch 65/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9212
# Epoch 66/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2226 - accuracy: 0.9208
# Epoch 67/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.9195
# Epoch 68/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2220 - accuracy: 0.9202
# Epoch 69/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9225
# Epoch 70/70
# 95/95 [==============================] - 0s 2ms/step - loss: 0.2204 - accuracy: 0.9212

# %%
import time

import numpy as np

start_time = time.time()
model.evaluate(x_test,y_test)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.8993
# Elapsed time to compute the importances: 0.260 seconds

# %%
yp = model.predict(x_test)
yp[:5]
y_pred = []
for ele in yp :
  if ele > 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)
# Out:
# 24/24 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       624
#            1       0.79      0.57      0.66       131
#
#     accuracy                           0.90       755
#    macro avg       0.85      0.77      0.80       755
# weighted avg       0.89      0.90      0.89       755

# %%
import seaborn as sn

cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,10))
sn.heatmap(cm,annot=True,fmt='d')
plt.title('Confusion matrix for ANN Model')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
df_clean.columns
# Out:
# Index(['Churn', 'Tenure', 'WarehouseToHome', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress',
#        'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount', 'PreferredLoginDevice_Computer',
#        'PreferredLoginDevice_Mobile Phone', 'PreferredPaymentMode_COD',
#        'PreferredPaymentMode_Credit Card', 'PreferredPaymentMode_Debit Card',
#        'PreferredPaymentMode_E wallet', 'PreferredPaymentMode_UPI',
#        'PreferedOrderCat_Fashion', 'PreferedOrderCat_Grocery',
#        'PreferedOrderCat_Laptop & Accessory', 'PreferedOrderCat_Mobile Phone',
#        'PreferedOrderCat_Others', 'MaritalStatus_Divorced',
#        'MaritalStatus_Married', 'MaritalStatus_Single', 'CityTier_1',
#        'CityTier_2', 'CityTier_3'],
#       dtype='object')

# %% [markdown]
# ##b. Decision Tree Prediction

# %%
#checking the prediction with Decision Tree Classifier
from sklearn.ensemble import RandomForestClassifier

feature_names = [x.columns[i] for i in range(x.shape[1])]
forest = RandomForestClassifier(random_state=0)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
from sklearn import tree
start_time = time.time()
y_pred_clf = clf.predict(x_test)
elapsed_time_DTC = time.time() - start_time

print(f"Elapsed time to compute with Decision Tree: {elapsed_time_DTC:.3f} seconds")
# Out:
# Elapsed time to compute with Decision Tree: 0.002 seconds

# %%
import seaborn as sn

cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_clf)

plt.figure(figsize = (10,10))
plt.title('Confusion matrix for RadomForest Model')
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test,y_pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       624
#            1       0.87      0.83      0.85       131
#
#     accuracy                           0.95       755
#    macro avg       0.92      0.90      0.91       755
# weighted avg       0.95      0.95      0.95       755

# %% [markdown]
# #3. Summary
#
# The Accuracy of the models that have been calculated for ANN(Neural Networks) and Decision Tree(Random Forest Classifier) are 0.91 and 0.94 respectively. The computation time for the respective algorithms are 0.12 secs and 0.03 secs. Hence we can conclude the Decision Tree works better and efficient with this dataset.
#
# As per the analysis we can conclude that the Churn actually depends on some of the features more than others. The features Tenure,PreferredLoginDevice,PreferredPaymentMode,PreferedOrderCat, CashbackAmount are more responsible for  churn of the users.
#
# ###Tenure
#
# People with lesser tenure are leaving the application soon but users with high tenure they are still with the application.
#
# ###PreferredLoginDevice
#
# Users with Mobile Device Logins are more into churn as per the data.
#
# ###PreferredPaymentMode
#
# Users with Debit/Credit card payments are churning.
#
# ###PreferredOrderCat
#
# Users with Search for Phones or Mobile Phones churned more.
#
# ###CashbackAmount
#
# Users who got churned had less Cashbacks than the ones not churned.

# %%
pp_df = df.filter(['Tenure','PreferredLoginDevice','PreferredPaymentMode','PreferredOrderCat','CashbackAmount','Churn'],axis = 1)
pp_df.head()
# Out:
#     Tenure PreferredLoginDevice PreferredPaymentMode  CashbackAmount  Churn
# 0        4         Mobile Phone           Debit Card          159.93      1
# 3        0         Mobile Phone           Debit Card          134.07      1
# 5        0             Computer           Debit Card          139.19      1
# 11      11         Mobile Phone           Debit Card          153.81      1
# 12       0         Mobile Phone                  COD          134.41      1

# %%
plt.figure(figsize=(7, 3))

plt.subplot(131)
plt.bar(pp_df['Churn'],pp_df['Tenure'])
plt.suptitle('Churn on the basis of Tenure')
plt.show()

# %%
pp_df.groupby(['Churn'])['PreferredLoginDevice'].value_counts()
# Out:
# Churn  PreferredLoginDevice
# 0      Mobile Phone            2244
#        Computer                 899
# 1      Mobile Phone             419
#        Computer                 212
# Name: PreferredLoginDevice, dtype: int64

# %%
pp_df.groupby(['Churn'])['PreferredPaymentMode'].value_counts()
# Out:
# Churn  PreferredPaymentMode
# 0      Debit Card              1308
#        Credit Card              980
#        E wallet                 349
#        COD                      269
#        UPI                      237
# 1      Debit Card               230
#        Credit Card              179
#        E wallet                  94
#        COD                       80
#        UPI                       48
# Name: PreferredPaymentMode, dtype: int64

# %%
churned = pp_df[pp_df['Churn'] == 1]
ch = churned['CashbackAmount'].sum()
print(f'Churned Cashback Amount : {ch}')

unchurned = pp_df[pp_df['Churn'] == 0]
un = unchurned['CashbackAmount'].sum()
print(f'Unchurned Cashback Amount : {un}')
# Out:
# Churned Cashback Amount : 101625.39
# Unchurned Cashback Amount : 518116.7

# %%
pp_df.groupby(by = ['PreferredPaymentMode','Churn'])['CashbackAmount'].sum()
# Out:
# PreferredPaymentMode  Churn
# COD                   0         44878.45
#                       1         12372.30
# Credit Card           0        158289.49
#                       1         28582.75
# Debit Card            0        216917.15
#                       1         36633.70
# E wallet              0         59599.99
#                       1         16468.38
# UPI                   0         38431.62
#                       1          7568.26
# Name: CashbackAmount, dtype: float64

# %% [markdown]
# As per above data we can see that;
#
# 1. Churn is mostly seen in the new users.
# 2. The churn is found mostly in Debit and Credit card users which can means that new users might not be getting better cash backs or better offers while using those cards on the application.
# 3. If we see further churn may also be happening due to Payment Login devices, both Computer and Mobile have churns but Mobile has more churn than Computer which indicates issues with UI or UX.
